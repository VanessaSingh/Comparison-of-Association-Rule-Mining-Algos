# %%
import sys
from itertools import chain, combinations
from collections import defaultdict
from optparse import OptionParser
from fim import apriori
from fim import fpgrowth
from fim import eclat
import time

# %%
file_iter = open('/home/vanessa/DWDM/ICC_Rankingsdiv.csv', 'rU')
tracts = []
for line in file_iter:
    line = line.strip().rstrip(',')                         # Remove trailing comma
    record = line.split(',')
#    print record
    tracts.append(record)
#print("-------------------")
#print tracts

# %%
xAxisap=[]
yAxisap=[]
for i in xrange(1, 10, 1):
    yAxisap.append(i)
    print  ('apriori(tracts, supp=',i,', zmin=2):')
    start = time.time()
    #print i
    for r in apriori(tracts, target = 's', supp = -i, conf = 10, zmin=2): 
        print (r) 
    xAxisap.append(time.time()-start)
# Out:
# ('apriori(tracts, supp=', 1, ', zmin=2):')
# (('13', 'Kenya'), 1)
# (('Netherlands', '12'), 1)
# (('12', 'Kenya'), 4)
# (('Ireland', '11'), 2)
# (('Ireland', '10'), 3)
# (('Bangladesh', '11'), 1)
# (('Bangladesh', '10'), 1)
# (('Bangladesh', '9'), 4)
# (('Bangladesh', '8'), 1)
# (('11', 'Kenya'), 1)
# (('11', 'Zimbabwe'), 3)
# (('Kenya', '10'), 1)
# (('10', 'Zimbabwe'), 2)
# (('Zimbabwe', '9'), 2)
# (('9', 'West Indies'), 1)
# (('New Zealand', '8'), 1)
# (('New Zealand', '7'), 1)
# (('New Zealand', '5'), 2)
# (('New Zealand', '4'), 2)
# (('New Zealand', '3'), 1)
# (('8', 'West Indies'), 5)
# (('West Indies', '7'), 1)
# (('7', 'England'), 2)
# (('7', 'Pakistan'), 1)
# (('7', 'Sri Lanka'), 2)
# (('England', '6'), 2)
# (('England', '5'), 2)
# (('England', '4'), 1)
# (('6', 'Pakistan'), 2)
# (('6', 'India'), 1)
# (('6', 'Sri Lanka'), 2)
# (('Pakistan', '5'), 3)
# (('Pakistan', '4'), 1)
# (('South Africa', '4'), 2)
# (('South Africa', '3'), 1)
# (('South Africa', '2'), 3)
# (('South Africa', '1'), 1)
# (('4', 'Sri Lanka'), 1)
# (('India', '3'), 3)
# (('India', '2'), 3)
# (('3', 'Sri Lanka'), 1)
# (('3', 'Australia'), 1)
# (('Sri Lanka', '2'), 1)
# (('Australia', '1'), 6)
# ('apriori(tracts, supp=', 2, ', zmin=2):')
# (('12', 'Kenya'), 4)
# (('Ireland', '11'), 2)
# (('Ireland', '10'), 3)
# (('1', 'Australia'), 6)
# (('Bangladesh', '9'), 4)
# (('11', 'Zimbabwe'), 3)
# (('10', 'Zimbabwe'), 2)
# (('Zimbabwe', '9'), 2)
# (('New Zealand', '5'), 2)
# (('New Zealand', '4'), 2)
# (('8', 'West Indies'), 5)
# (('7', 'England'), 2)
# (('7', 'Sri Lanka'), 2)
# (('England', '6'), 2)
# (('England', '5'), 2)
# (('6', 'Pakistan'), 2)
# (('6', 'Sri Lanka'), 2)
# (('Pakistan', '5'), 3)
# (('South Africa', '4'), 2)
# (('South Africa', '2'), 3)
# (('India', '3'), 3)
# (('India', '2'), 3)
# ('apriori(tracts, supp=', 3, ', zmin=2):')
# (('12', 'Kenya'), 4)
# (('Ireland', '10'), 3)
# (('1', 'Australia'), 6)
# (('Bangladesh', '9'), 4)
# (('11', 'Zimbabwe'), 3)
# (('8', 'West Indies'), 5)
# (('Pakistan', '5'), 3)
# (('South Africa', '2'), 3)
# (('India', '3'), 3)
# (('India', '2'), 3)
# ('apriori(tracts, supp=', 4, ', zmin=2):')
# (('12', 'Kenya'), 4)
# (('1', 'Australia'), 6)
# (('Bangladesh', '9'), 4)
# (('8', 'West Indies'), 5)
# ('apriori(tracts, supp=', 5, ', zmin=2):')
# (('1', 'Australia'), 6)
# (('8', 'West Indies'), 5)
# ('apriori(tracts, supp=', 6, ', zmin=2):')
# (('1', 'Australia'), 6)
# ('apriori(tracts, supp=', 7, ', zmin=2):')
# ('apriori(tracts, supp=', 8, ', zmin=2):')
# ('apriori(tracts, supp=', 9, ', zmin=2):')

# %%
xAxisfp=[]
yAxisfp=[]
for i in xrange(1, 10, 1):
    yAxisfp.append(i)
    print  ('apriori(tracts, supp=',i,', zmin=2):')
    start = time.time()
    #print i
    for r in fpgrowth(tracts, target = 'r', supp = -i, conf = 10, zmin=2): 
        print (r) 
    xAxisfp.append(time.time()-start)
# Out:
# ('apriori(tracts, supp=', 1, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('11', ('Ireland',), 2)
# ('Ireland', ('11',), 2)
# ('10', ('Ireland',), 3)
# ('Ireland', ('10',), 3)
# ('Kenya', ('12',), 4)
# ('12', ('Kenya',), 4)
# ('12', ('Netherlands',), 1)
# ('Netherlands', ('12',), 1)
# ('Kenya', ('13',), 1)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 2, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('11', ('Ireland',), 2)
# ('Ireland', ('11',), 2)
# ('10', ('Ireland',), 3)
# ('Ireland', ('10',), 3)
# ('Kenya', ('12',), 4)
# ('12', ('Kenya',), 4)
# ('Netherlands', ('12',), 1)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 3, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('11', ('Ireland',), 2)
# ('Ireland', ('11',), 2)
# ('10', ('Ireland',), 3)
# ('Ireland', ('10',), 3)
# ('Kenya', ('12',), 4)
# ('12', ('Kenya',), 4)
# ('Netherlands', ('12',), 1)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 4, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('11', ('Ireland',), 2)
# ('Ireland', ('11',), 2)
# ('10', ('Ireland',), 3)
# ('Ireland', ('10',), 3)
# ('Kenya', ('12',), 4)
# ('12', ('Kenya',), 4)
# ('Netherlands', ('12',), 1)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 5, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('11', ('Ireland',), 2)
# ('Ireland', ('11',), 2)
# ('10', ('Ireland',), 3)
# ('Ireland', ('10',), 3)
# ('Kenya', ('12',), 4)
# ('12', ('Kenya',), 4)
# ('Netherlands', ('12',), 1)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 6, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('Ireland', ('11',), 2)
# ('Ireland', ('10',), 3)
# ('12', ('Kenya',), 4)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 7, ', zmin=2):')
# ('Bangladesh', ('11',), 1)
# ('11', ('Bangladesh',), 1)
# ('11', ('Kenya',), 1)
# ('Kenya', ('11',), 1)
# ('Bangladesh', ('10',), 1)
# ('10', ('Bangladesh',), 1)
# ('Kenya', ('10',), 1)
# ('10', ('Kenya',), 1)
# ('11', ('Zimbabwe',), 3)
# ('Zimbabwe', ('11',), 3)
# ('10', ('Zimbabwe',), 2)
# ('Zimbabwe', ('10',), 2)
# ('Bangladesh', ('9',), 4)
# ('9', ('Bangladesh',), 4)
# ('Zimbabwe', ('9',), 2)
# ('9', ('Zimbabwe',), 2)
# ('Bangladesh', ('8',), 1)
# ('8', ('Bangladesh',), 1)
# ('New Zealand', ('8',), 1)
# ('8', ('New Zealand',), 1)
# ('9', ('West Indies',), 1)
# ('West Indies', ('9',), 1)
# ('8', ('West Indies',), 5)
# ('West Indies', ('8',), 5)
# ('New Zealand', ('7',), 1)
# ('7', ('New Zealand',), 1)
# ('West Indies', ('7',), 1)
# ('7', ('West Indies',), 1)
# ('7', ('England',), 2)
# ('England', ('7',), 2)
# ('England', ('6',), 2)
# ('6', ('England',), 2)
# ('7', ('Pakistan',), 1)
# ('Pakistan', ('7',), 1)
# ('6', ('Pakistan',), 2)
# ('Pakistan', ('6',), 2)
# ('New Zealand', ('5',), 2)
# ('5', ('New Zealand',), 2)
# ('England', ('5',), 2)
# ('5', ('England',), 2)
# ('Pakistan', ('5',), 3)
# ('5', ('Pakistan',), 3)
# ('1', ('South Africa',), 1)
# ('South Africa', ('1',), 1)
# ('New Zealand', ('4',), 2)
# ('4', ('New Zealand',), 2)
# ('England', ('4',), 1)
# ('4', ('England',), 1)
# ('Pakistan', ('4',), 1)
# ('4', ('Pakistan',), 1)
# ('South Africa', ('4',), 2)
# ('4', ('South Africa',), 2)
# ('6', ('India',), 1)
# ('India', ('6',), 1)
# ('New Zealand', ('3',), 1)
# ('3', ('New Zealand',), 1)
# ('South Africa', ('3',), 1)
# ('3', ('South Africa',), 1)
# ('India', ('3',), 3)
# ('3', ('India',), 3)
# ('7', ('Sri Lanka',), 2)
# ('Sri Lanka', ('7',), 2)
# ('6', ('Sri Lanka',), 2)
# ('Sri Lanka', ('6',), 2)
# ('4', ('Sri Lanka',), 1)
# ('Sri Lanka', ('4',), 1)
# ('3', ('Sri Lanka',), 1)
# ('Sri Lanka', ('3',), 1)
# ('South Africa', ('2',), 3)
# ('2', ('South Africa',), 3)
# ('India', ('2',), 3)
# ('2', ('India',), 3)
# ('Sri Lanka', ('2',), 1)
# ('2', ('Sri Lanka',), 1)
# ('1', ('Australia',), 6)
# ('Australia', ('1',), 6)
# ('3', ('Australia',), 1)
# ('Australia', ('3',), 1)
# ('Ireland', ('11',), 2)
# ('Ireland', ('10',), 3)
# ('12', ('Kenya',), 4)
# ('13', ('Kenya',), 1)
# ('apriori(tracts, supp=', 8, ', zmin=2):')
# ('apriori(tracts, supp=', 9, ', zmin=2):')

# %%
xAxisec=[]
yAxisec=[]
for i in xrange(1, 10, 1):
    yAxisec.append(i)
    print  ('apriori(tracts, supp=',i,', zmin=2):')
    start = time.time()
    #print i
    for r in eclat(tracts, target = 's', supp = -i, conf = 10, zmin=2): 
        print (r) 
    xAxisec.append(time.time()-start)
# Out:
# ('apriori(tracts, supp=', 1, ', zmin=2):')
# (('10', 'Kenya'), 1)
# (('Zimbabwe', '10'), 2)
# (('9', 'Zimbabwe'), 2)
# (('8', 'New Zealand'), 1)
# (('West Indies', '9'), 1)
# (('West Indies', '8'), 5)
# (('7', 'New Zealand'), 1)
# (('7', 'West Indies'), 1)
# (('England', '7'), 2)
# (('6', 'England'), 2)
# (('Pakistan', '7'), 1)
# (('Pakistan', '6'), 2)
# (('5', 'New Zealand'), 2)
# (('5', 'England'), 2)
# (('5', 'Pakistan'), 3)
# (('South Africa', '1'), 1)
# (('4', 'New Zealand'), 2)
# (('4', 'England'), 1)
# (('4', 'Pakistan'), 1)
# (('4', 'South Africa'), 2)
# (('India', '6'), 1)
# (('3', 'India'), 3)
# (('3', 'South Africa'), 1)
# (('3', 'New Zealand'), 1)
# (('Sri Lanka', '7'), 2)
# (('Sri Lanka', '6'), 2)
# (('Sri Lanka', '3'), 1)
# (('Sri Lanka', '4'), 1)
# (('2', 'South Africa'), 3)
# (('2', 'India'), 3)
# (('2', 'Sri Lanka'), 1)
# (('Australia', '1'), 6)
# (('Australia', '3'), 1)
# (('Bangladesh', '9'), 4)
# (('Bangladesh', '8'), 1)
# (('Bangladesh', '10'), 1)
# (('11', 'Zimbabwe'), 3)
# (('11', 'Bangladesh'), 1)
# (('11', 'Kenya'), 1)
# (('Ireland', '10'), 3)
# (('Ireland', '11'), 2)
# (('12', 'Kenya'), 4)
# (('Netherlands', '12'), 1)
# (('13', 'Kenya'), 1)
# ('apriori(tracts, supp=', 2, ', zmin=2):')
# (('Zimbabwe', '11'), 3)
# (('Zimbabwe', '10'), 2)
# (('9', 'Zimbabwe'), 2)
# (('West Indies', '8'), 5)
# (('England', '7'), 2)
# (('6', 'England'), 2)
# (('Pakistan', '6'), 2)
# (('5', 'New Zealand'), 2)
# (('5', 'England'), 2)
# (('5', 'Pakistan'), 3)
# (('4', 'New Zealand'), 2)
# (('4', 'South Africa'), 2)
# (('3', 'India'), 3)
# (('Sri Lanka', '6'), 2)
# (('Sri Lanka', '7'), 2)
# (('2', 'India'), 3)
# (('2', 'South Africa'), 3)
# (('Australia', '1'), 6)
# (('Bangladesh', '9'), 4)
# (('Ireland', '10'), 3)
# (('Ireland', '11'), 2)
# (('12', 'Kenya'), 4)
# ('apriori(tracts, supp=', 3, ', zmin=2):')
# (('Zimbabwe', '11'), 3)
# (('West Indies', '8'), 5)
# (('5', 'Pakistan'), 3)
# (('3', 'India'), 3)
# (('2', 'India'), 3)
# (('2', 'South Africa'), 3)
# (('Australia', '1'), 6)
# (('Bangladesh', '9'), 4)
# (('Ireland', '10'), 3)
# (('12', 'Kenya'), 4)
# ('apriori(tracts, supp=', 4, ', zmin=2):')
# (('West Indies', '8'), 5)
# (('Australia', '1'), 6)
# (('Bangladesh', '9'), 4)
# (('12', 'Kenya'), 4)
# ('apriori(tracts, supp=', 5, ', zmin=2):')
# (('West Indies', '8'), 5)
# (('Australia', '1'), 6)
# ('apriori(tracts, supp=', 6, ', zmin=2):')
# (('Australia', '1'), 6)
# ('apriori(tracts, supp=', 7, ', zmin=2):')
# ('apriori(tracts, supp=', 8, ', zmin=2):')
# ('apriori(tracts, supp=', 9, ', zmin=2):')

# %%
print xAxisap
print yAxisap
import numpy as np
print(np.average(xAxisap))
# Out:
# [0.006201982498168945, 0.0029511451721191406, 0.0013051033020019531, 0.0007038116455078125, 0.0003581047058105469, 0.00023293495178222656, 0.00011301040649414062, 7.796287536621094e-05, 7.510185241699219e-05]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 0.00133546193441

# %%
print xAxisfp
print yAxisfp
import numpy as np
print(np.average(xAxisfp))
# Out:
# [0.011512041091918945, 0.013367891311645508, 0.013748884201049805, 0.014073848724365234, 0.013659000396728516, 0.012166976928710938, 0.009775876998901367, 0.00010609626770019531, 6.103515625e-05]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 0.00983018345303

# %%
print xAxisec
print yAxisec
import numpy as np
print(np.average(xAxisec))
# Out:
# [0.02863597869873047, 0.0017001628875732422, 0.0015468597412109375, 0.0006279945373535156, 0.0005130767822265625, 0.00039315223693847656, 0.00013113021850585938, 7.390975952148438e-05, 7.104873657226562e-05]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# 0.00374370151096

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.set_color_cycle(['blue', 'green', 'orange'])
plt.plot(yAxisap, xAxisap)
plt.plot(yAxisfp, xAxisfp)
plt.plot(yAxisec, xAxisec)
# Out:
# /home/vanessa/anaconda2/lib/python2.7/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)

# %%
plt.show()
